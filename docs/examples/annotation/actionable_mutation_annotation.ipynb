# %% [markdown]
# # OncoKB Annotation Demo
#
# This notebook demonstrates how to use the `export_oncokb_input` method to annotate genomic variants with OncoKB data:
#
# - A MAF file with GRCh37 assembly: `tcga_laml.maf.gz`
#
# The notebook will show how to load these files, annotate them with OncoKB data, and display the resulting annotations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import logging
import requests


# Import necessary functions
from pyMut.input import read_maf, read_vcf

# %% [markdown]
# ## Get OncoKB API Token
#
# We need an OncoKB API token to use the annotation service. We'll try to read it from a .env file.

# %%
# Get the OncoKB API token
import os

def read_oncokb_token(env_path):
    """Read OncoKB API token from .env file"""
    try:
        # Try using python-dotenv if available
        from dotenv import load_dotenv
        load_dotenv(env_path)
        return os.getenv('ONCOKB_API')
    except ImportError:
        # Manual parsing if python-dotenv is not available
        if env_path.exists():
            with open(env_path, 'r') as f:
                for line in f:
                    if line.startswith('ONCOKB_API='):
                        return line.split('=', 1)[1].strip()
        return None

env_path = Path("../../../.env")
oncokb_token = read_oncokb_token(env_path)

if not oncokb_token:
    logging.warning("OncoKB API token not found. Please create a .env file with ONCOKB_API=your_token")
    # For demonstration purposes, you can enter your token manually:
    oncokb_token = input("Enter your OncoKB token: ")
else:
    logging.info("OncoKB API token loaded successfully")
# Out:
# 2025-10-12 08:51:11,915 | INFO | root | OncoKB API token loaded successfully

# %% [markdown]
# ## Monitor API Requests
#
# We'll add a monkey patch to monitor API requests and responses for debugging purposes.

# %%
# Add a monkey patch to log API requests and responses
original_post = requests.Session.post

def logging_post(*args, **kwargs):
    logging.info(f"API Request URL: {args[1]}")
    response = original_post(*args, **kwargs)
    logging.info(f"API Response Status Code: {response.status_code}")
    return response

# %% [markdown]
# ## Process MAF File (GRCh37)
#
# Now, we'll load and annotate the MAF file with GRCh37 assembly.

# %%
# Define the path to the MAF file
maf_path = "../../../src/pyMut/data/examples/MAF/tcga_laml.maf.gz"

# Load the MAF file with assembly 37
logging.info(f"Loading MAF file: {maf_path}")
maf_py_mut = read_maf(maf_path, assembly="37")

# Display basic information about the loaded data
logging.info(f"Loaded {len(maf_py_mut.data)} variants from MAF file")
logging.info(f"Assembly: {maf_py_mut.metadata.assembly}")

# Show the first few rows of the data
print("\nSample of MAF data before annotation:")
display(maf_py_mut.data.head())
# Out:
# 2025-10-12 08:51:12,011 | INFO | root | Loading MAF file: ../../../src/pyMut/data/examples/MAF/tcga_laml.maf.gz
# 2025-10-12 08:51:12,012 | INFO | pyMut.input | Starting MAF reading: ../../../src/pyMut/data/examples/MAF/tcga_laml.maf.gz
# 2025-10-12 08:51:12,013 | INFO | pyMut.input | Loading from cache: ../../../src/pyMut/data/examples/MAF/.pymut_cache/tcga_laml.maf_6d31582be6bf0b0b.parquet
# 2025-10-12 08:51:12,050 | INFO | pyMut.input | Cache loaded successfully in 0.04 seconds
# 2025-10-12 08:51:12,050 | INFO | root | Loaded 2091 variants from MAF file
# 2025-10-12 08:51:12,051 | INFO | root | Assembly: 37
# Sample of MAF data before annotation:
#   CHROM        POS ID REF ALT QUAL FILTER TCGA-AB-2988 TCGA-AB-2869  \
# 0  chr9  100077177  .   T   C    .      .          T|T          T|T
# 1  chr9  100085148  .   G   A    .      .          G|G          G|G
# 2  chr9  100971322  .   A   C    .      .          A|A          A|A
# 3  chr9  104086335  .   C   T    .      .          C|C          C|C
# 4  chr9  104124840  .   G   A    .      .          G|A          G|G
#
#   TCGA-AB-3009  ... Strand Variant_Classification Variant_Type  \
# 0          T|T  ...      +                 SILENT          SNP
# 1          G|G  ...      +      MISSENSE_MUTATION          SNP
# 2          A|A  ...      +      MISSENSE_MUTATION          SNP
# 3          C|C  ...      +      MISSENSE_MUTATION          SNP
# 4          G|G  ...      +      MISSENSE_MUTATION          SNP
#
#   Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2 Tumor_Sample_Barcode  \
# 0                T                 T                 C         TCGA-AB-2886
# 1                G                 G                 A         TCGA-AB-2917
# 2                A                 A                 C         TCGA-AB-2841
# 3                C                 C                 T         TCGA-AB-2877
# 4                G                 G                 A         TCGA-AB-2988
#
#   Protein_Change i_TumorVAF_WU i_transcript_name
# 0        p.T431T          9.76       NM_020893.1
# 1        p.R581H          18.4       NM_020893.1
# 2        p.L593R         45.83       NM_018421.3
# 3        p.T325I         37.12       NM_017753.2
# 4        p.T376M         48.35       NM_001701.1
#
# [5 rows x 216 columns]

# %% [markdown]
# ### Annotate MAF data with OncoKB

# %%
# Annotate the MAF data with OncoKB
if oncokb_token:
    logging.info("Annotating MAF data with OncoKB...")
    try:
        # Apply the monitoring patch
        requests.Session.post = logging_post
        
        # Perform the annotation
        maf_annotated_data = maf_py_mut.actionable_mutations_oncokb(
            token=oncokb_token,
            batch_size=1000,
            timeout=30,
            max_retries=3,
            retry_backoff=1.0
        )
        
        # Restore the original post method
        requests.Session.post = original_post
        
        # Show the first few rows of the annotated data
        print("\nSample of MAF data after annotation:")
        display(maf_py_mut.data.head())
        
        # Show annotation statistics
        def show_annotation_stats(py_mut_obj, dataset_name):
            """Show basic annotation statistics"""
            oncokb_columns = [col for col in py_mut_obj.data.columns if col.startswith('oncokb_')]
            if oncokb_columns:
                print(f"\n{dataset_name} - OncoKB annotation statistics:")
                for col in oncokb_columns:
                    non_null_count = py_mut_obj.data[col].notna().sum()
                    print(f"  {col}: {non_null_count} variants")
            else:
                print(f"\n{dataset_name} - No OncoKB annotations found")
        
        show_annotation_stats(maf_py_mut, "MAF File (GRCh37)")
        
    except Exception as e:
        logging.error(f"Error during OncoKB annotation for MAF: {e}")
        # Restore the original post method
        requests.Session.post = original_post
else:
    logging.error("Cannot perform annotation without a valid OncoKB token")
# Out:
# 2025-10-12 08:51:12,088 | INFO | root | Annotating MAF data with OncoKB...
# 2025-10-12 08:51:12,089 | INFO | pyMut.annotate.actionable_mutation | Using reference genome: GRCh37
# 2025-10-12 08:51:12,093 | INFO | pyMut.annotate.actionable_mutation | Splitting 2091 variants into 3 batches of max 1000 variants each
# /home/luisruimore/anaconda3/envs/PyMutTFG/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# 2025-10-12 08:51:12,094 | INFO | pyMut.annotate.actionable_mutation | Processing batch 1/3 with 697 variants
# 2025-10-12 08:51:12,130 | INFO | pyMut.annotate.actionable_mutation | Sending batch 1/3 to OncoKB API
# 2025-10-12 08:51:12,130 | INFO | root | API Request URL: https://www.oncokb.org/api/v1/annotate/mutations/byGenomicChange
# 2025-10-12 08:51:13,962 | INFO | root | API Response Status Code: 200
# 2025-10-12 08:51:13,972 | INFO | pyMut.annotate.actionable_mutation | Batch 1/3 processed successfully
# 2025-10-12 08:51:13,973 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 0 in batch 1
# 2025-10-12 08:51:13,973 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 0 in batch 1
# 2025-10-12 08:51:13,974 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 1 in batch 1
# 2025-10-12 08:51:13,974 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 1 in batch 1
# 2025-10-12 08:51:13,974 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 2 in batch 1
# 2025-10-12 08:51:13,975 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 2 in batch 1
# 2025-10-12 08:51:13,975 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 3 in batch 1
# 2025-10-12 08:51:13,975 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 3 in batch 1
# 2025-10-12 08:51:13,975 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 4 in batch 1
# 2025-10-12 08:51:13,976 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 4 in batch 1
# 2025-10-12 08:51:13,976 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 5 in batch 1
# 2025-10-12 08:51:13,976 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 5 in batch 1
# 2025-10-12 08:51:13,977 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 6 in batch 1
# 2025-10-12 08:51:13,977 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 6 in batch 1
# 2025-10-12 08:51:13,977 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 7 in batch 1
# 2025-10-12 08:51:13,978 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 7 in batch 1
# 2025-10-12 08:51:13,981 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 8 in batch 1
# 2025-10-12 08:51:13,981 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 8 in batch 1
# 2025-10-12 08:51:13,982 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 9 in batch 1
# 2025-10-12 08:51:13,982 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 9 in batch 1
# 2025-10-12 08:51:13,983 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 10 in batch 1
# 2025-10-12 08:51:13,984 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 10 in batch 1
# 2025-10-12 08:51:13,984 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 11 in batch 1
# 2025-10-12 08:51:13,984 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 11 in batch 1
# 2025-10-12 08:51:13,984 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 12 in batch 1
# 2025-10-12 08:51:13,985 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 12 in batch 1
# 2025-10-12 08:51:13,985 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 13 in batch 1
# 2025-10-12 08:51:13,985 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 13 in batch 1
# 2025-10-12 08:51:13,985 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 14 in batch 1
# 2025-10-12 08:51:13,986 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 14 in batch 1
# 2025-10-12 08:51:13,986 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 15 in batch 1
# 2025-10-12 08:51:13,987 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 15 in batch 1
# 2025-10-12 08:51:13,987 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 16 in batch 1
# 2025-10-12 08:51:13,987 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 16 in batch 1
# 2025-10-12 08:51:13,988 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 17 in batch 1
# 2025-10-12 08:51:13,988 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 17 in batch 1
# 2025-10-12 08:51:13,988 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 18 in batch 1
# 2025-10-12 08:51:13,989 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 18 in batch 1
# 2025-10-12 08:51:13,989 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 19 in batch 1
# 2025-10-12 08:51:13,989 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 19 in batch 1
# 2025-10-12 08:51:13,989 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 20 in batch 1
# 2025-10-12 08:51:13,990 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 20 in batch 1
# 2025-10-12 08:51:13,990 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 21 in batch 1
# 2025-10-12 08:51:13,990 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 22 in batch 1
# 2025-10-12 08:51:13,991 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 22 in batch 1
# 2025-10-12 08:51:13,991 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 23 in batch 1
# 2025-10-12 08:51:13,991 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 23 in batch 1
# 2025-10-12 08:51:13,991 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 24 in batch 1
# 2025-10-12 08:51:13,993 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 24 in batch 1
# 2025-10-12 08:51:13,993 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 25 in batch 1
# 2025-10-12 08:51:13,993 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 25 in batch 1
# 2025-10-12 08:51:13,994 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 26 in batch 1
# 2025-10-12 08:51:13,994 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 27 in batch 1
# 2025-10-12 08:51:13,994 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 27 in batch 1
# 2025-10-12 08:51:13,995 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 28 in batch 1
# 2025-10-12 08:51:13,995 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 28 in batch 1
# 2025-10-12 08:51:13,995 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 29 in batch 1
# 2025-10-12 08:51:13,996 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 29 in batch 1
# 2025-10-12 08:51:13,996 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 30 in batch 1
# 2025-10-12 08:51:13,997 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 30 in batch 1
# 2025-10-12 08:51:13,997 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 31 in batch 1
# 2025-10-12 08:51:13,997 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 31 in batch 1
# 2025-10-12 08:51:13,998 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 32 in batch 1
# 2025-10-12 08:51:13,998 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 32 in batch 1
# 2025-10-12 08:51:13,998 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 33 in batch 1
# 2025-10-12 08:51:13,999 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 33 in batch 1
# 2025-10-12 08:51:13,999 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 34 in batch 1
# 2025-10-12 08:51:13,999 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 34 in batch 1
# 2025-10-12 08:51:14,000 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 35 in batch 1
# 2025-10-12 08:51:14,000 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 36 in batch 1
# 2025-10-12 08:51:14,000 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 36 in batch 1
# 2025-10-12 08:51:14,001 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 37 in batch 1
# 2025-10-12 08:51:14,001 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 38 in batch 1
# 2025-10-12 08:51:14,001 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 38 in batch 1
# 2025-10-12 08:51:14,002 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 39 in batch 1
# 2025-10-12 08:51:14,002 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 39 in batch 1
# 2025-10-12 08:51:14,002 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 40 in batch 1
# 2025-10-12 08:51:14,003 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 40 in batch 1
# 2025-10-12 08:51:14,003 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 41 in batch 1
# 2025-10-12 08:51:14,003 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 41 in batch 1
# 2025-10-12 08:51:14,004 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 42 in batch 1
# 2025-10-12 08:51:14,004 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 42 in batch 1
# 2025-10-12 08:51:14,005 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 43 in batch 1
# 2025-10-12 08:51:14,005 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 43 in batch 1
# 2025-10-12 08:51:14,005 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 44 in batch 1
# 2025-10-12 08:51:14,006 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 44 in batch 1
# 2025-10-12 08:51:14,006 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 45 in batch 1
# 2025-10-12 08:51:14,007 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 45 in batch 1
# 2025-10-12 08:51:14,007 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 46 in batch 1
# 2025-10-12 08:51:14,007 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 46 in batch 1
# 2025-10-12 08:51:14,008 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 47 in batch 1
# 2025-10-12 08:51:14,009 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 47 in batch 1
# 2025-10-12 08:51:14,009 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 48 in batch 1
# 2025-10-12 08:51:14,009 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 48 in batch 1
# 2025-10-12 08:51:14,009 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 49 in batch 1
# 2025-10-12 08:51:14,010 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 49 in batch 1
# 2025-10-12 08:51:14,010 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 50 in batch 1
# 2025-10-12 08:51:14,011 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 50 in batch 1
# 2025-10-12 08:51:14,011 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 51 in batch 1
# 2025-10-12 08:51:14,012 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 51 in batch 1
# 2025-10-12 08:51:14,012 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 52 in batch 1
# 2025-10-12 08:51:14,012 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 52 in batch 1
# 2025-10-12 08:51:14,013 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 53 in batch 1
# 2025-10-12 08:51:14,013 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 54 in batch 1
# 2025-10-12 08:51:14,013 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 54 in batch 1
# 2025-10-12 08:51:14,013 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 55 in batch 1
# 2025-10-12 08:51:14,014 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 55 in batch 1
# 2025-10-12 08:51:14,014 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 56 in batch 1
# 2025-10-12 08:51:14,015 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 56 in batch 1
# 2025-10-12 08:51:14,015 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 57 in batch 1
# 2025-10-12 08:51:14,016 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 57 in batch 1
# 2025-10-12 08:51:14,016 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 58 in batch 1
# 2025-10-12 08:51:14,016 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 58 in batch 1
# 2025-10-12 08:51:14,017 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 59 in batch 1
# 2025-10-12 08:51:14,017 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 60 in batch 1
# 2025-10-12 08:51:14,017 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 61 in batch 1
# 2025-10-12 08:51:14,018 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 61 in batch 1
# 2025-10-12 08:51:14,018 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 62 in batch 1
# 2025-10-12 08:51:14,019 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 62 in batch 1
# 2025-10-12 08:51:14,020 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 63 in batch 1
# 2025-10-12 08:51:14,020 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 63 in batch 1
# 2025-10-12 08:51:14,020 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 64 in batch 1
# 2025-10-12 08:51:14,021 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 64 in batch 1
# 2025-10-12 08:51:14,021 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 65 in batch 1
# 2025-10-12 08:51:14,022 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 65 in batch 1
# 2025-10-12 08:51:14,022 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 66 in batch 1
# 2025-10-12 08:51:14,022 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 66 in batch 1
# 2025-10-12 08:51:14,024 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 67 in batch 1
# 2025-10-12 08:51:14,024 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 67 in batch 1
# 2025-10-12 08:51:14,024 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 68 in batch 1
# 2025-10-12 08:51:14,025 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 68 in batch 1
# 2025-10-12 08:51:14,025 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 69 in batch 1
# 2025-10-12 08:51:14,025 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 69 in batch 1
# 2025-10-12 08:51:14,026 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 70 in batch 1
# 2025-10-12 08:51:14,026 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 70 in batch 1
# 2025-10-12 08:51:14,026 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 71 in batch 1
# 2025-10-12 08:51:14,026 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 71 in batch 1
# 2025-10-12 08:51:14,027 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 72 in batch 1
# 2025-10-12 08:51:14,027 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 72 in batch 1
# 2025-10-12 08:51:14,028 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 73 in batch 1
# 2025-10-12 08:51:14,028 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 73 in batch 1
# 2025-10-12 08:51:14,028 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 74 in batch 1
# 2025-10-12 08:51:14,028 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 74 in batch 1
# 2025-10-12 08:51:14,029 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 75 in batch 1
# 2025-10-12 08:51:14,029 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 75 in batch 1
# 2025-10-12 08:51:14,029 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 76 in batch 1
# 2025-10-12 08:51:14,030 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 76 in batch 1
# 2025-10-12 08:51:14,031 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 77 in batch 1
# 2025-10-12 08:51:14,031 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 77 in batch 1
# 2025-10-12 08:51:14,031 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 78 in batch 1
# 2025-10-12 08:51:14,032 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 78 in batch 1
# 2025-10-12 08:51:14,032 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 79 in batch 1
# 2025-10-12 08:51:14,032 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 79 in batch 1
# 2025-10-12 08:51:14,033 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 87 in batch 1
# 2025-10-12 08:51:14,033 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 88 in batch 1
# 2025-10-12 08:51:14,033 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 88 in batch 1
# 2025-10-12 08:51:14,034 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 89 in batch 1
# 2025-10-12 08:51:14,034 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 89 in batch 1
# 2025-10-12 08:51:14,034 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 90 in batch 1
# 2025-10-12 08:51:14,034 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 90 in batch 1
# 2025-10-12 08:51:14,035 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 91 in batch 1
# 2025-10-12 08:51:14,035 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 91 in batch 1
# 2025-10-12 08:51:14,035 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 96 in batch 1
# 2025-10-12 08:51:14,036 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 97 in batch 1
# 2025-10-12 08:51:14,037 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 98 in batch 1
# 2025-10-12 08:51:14,037 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 98 in batch 1
# 2025-10-12 08:51:14,037 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 99 in batch 1
# 2025-10-12 08:51:14,038 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 99 in batch 1
# 2025-10-12 08:51:14,038 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 100 in batch 1
# 2025-10-12 08:51:14,038 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 101 in batch 1
# 2025-10-12 08:51:14,039 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 102 in batch 1
# 2025-10-12 08:51:14,039 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 102 in batch 1
# 2025-10-12 08:51:14,039 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 103 in batch 1
# 2025-10-12 08:51:14,040 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 103 in batch 1
# 2025-10-12 08:51:14,040 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 104 in batch 1
# 2025-10-12 08:51:14,040 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 104 in batch 1
# 2025-10-12 08:51:14,041 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 105 in batch 1
# 2025-10-12 08:51:14,042 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 105 in batch 1
# 2025-10-12 08:51:14,042 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 106 in batch 1
# 2025-10-12 08:51:14,042 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 106 in batch 1
# 2025-10-12 08:51:14,043 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 107 in batch 1
# 2025-10-12 08:51:14,043 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 107 in batch 1
# 2025-10-12 08:51:14,043 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 108 in batch 1
# 2025-10-12 08:51:14,044 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 108 in batch 1
# 2025-10-12 08:51:14,044 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 109 in batch 1
# 2025-10-12 08:51:14,044 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 109 in batch 1
# 2025-10-12 08:51:14,045 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 110 in batch 1
# 2025-10-12 08:51:14,045 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 110 in batch 1
# 2025-10-12 08:51:14,045 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 111 in batch 1
# 2025-10-12 08:51:14,046 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 111 in batch 1
# 2025-10-12 08:51:14,046 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 112 in batch 1
# 2025-10-12 08:51:14,047 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 112 in batch 1
# 2025-10-12 08:51:14,047 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 113 in batch 1
# 2025-10-12 08:51:14,047 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 113 in batch 1
# 2025-10-12 08:51:14,048 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 114 in batch 1
# 2025-10-12 08:51:14,048 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 114 in batch 1
# 2025-10-12 08:51:14,049 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 115 in batch 1
# 2025-10-12 08:51:14,049 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 115 in batch 1
# 2025-10-12 08:51:14,049 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 116 in batch 1
# 2025-10-12 08:51:14,049 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 116 in batch 1
# 2025-10-12 08:51:14,050 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 117 in batch 1
# 2025-10-12 08:51:14,050 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 117 in batch 1
# 2025-10-12 08:51:14,050 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 118 in batch 1
# 2025-10-12 08:51:14,051 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 118 in batch 1
# 2025-10-12 08:51:14,051 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 119 in batch 1
# 2025-10-12 08:51:14,051 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 119 in batch 1
# 2025-10-12 08:51:14,052 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 120 in batch 1
# 2025-10-12 08:51:14,054 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 120 in batch 1
# 2025-10-12 08:51:14,055 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 121 in batch 1
# 2025-10-12 08:51:14,056 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 121 in batch 1
# 2025-10-12 08:51:14,057 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 122 in batch 1
# 2025-10-12 08:51:14,057 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 122 in batch 1
# 2025-10-12 08:51:14,057 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 123 in batch 1
# 2025-10-12 08:51:14,058 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 123 in batch 1
# 2025-10-12 08:51:14,058 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 124 in batch 1
# 2025-10-12 08:51:14,058 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 124 in batch 1
# 2025-10-12 08:51:14,059 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 125 in batch 1
# 2025-10-12 08:51:14,060 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 125 in batch 1
# 2025-10-12 08:51:14,060 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 126 in batch 1
# 2025-10-12 08:51:14,061 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 126 in batch 1
# 2025-10-12 08:51:14,061 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 127 in batch 1
# 2025-10-12 08:51:14,062 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 127 in batch 1
# 2025-10-12 08:51:14,062 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 128 in batch 1
# 2025-10-12 08:51:14,063 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 128 in batch 1
# 2025-10-12 08:51:14,064 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 129 in batch 1
# 2025-10-12 08:51:14,064 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 129 in batch 1
# 2025-10-12 08:51:14,064 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 130 in batch 1
# 2025-10-12 08:51:14,065 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 130 in batch 1
# 2025-10-12 08:51:14,065 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 131 in batch 1
# 2025-10-12 08:51:14,066 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 131 in batch 1
# 2025-10-12 08:51:14,066 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 132 in batch 1
# 2025-10-12 08:51:14,068 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 132 in batch 1
# 2025-10-12 08:51:14,068 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 135 in batch 1
# 2025-10-12 08:51:14,068 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 135 in batch 1
# 2025-10-12 08:51:14,069 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 136 in batch 1
# 2025-10-12 08:51:14,070 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 136 in batch 1
# 2025-10-12 08:51:14,070 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 137 in batch 1
# 2025-10-12 08:51:14,071 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 137 in batch 1
# 2025-10-12 08:51:14,071 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 138 in batch 1
# 2025-10-12 08:51:14,073 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 138 in batch 1
# 2025-10-12 08:51:14,076 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 139 in batch 1
# 2025-10-12 08:51:14,077 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 139 in batch 1
# 2025-10-12 08:51:14,078 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 140 in batch 1
# 2025-10-12 08:51:14,078 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 141 in batch 1
# 2025-10-12 08:51:14,079 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 143 in batch 1
# 2025-10-12 08:51:14,080 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 143 in batch 1
# 2025-10-12 08:51:14,080 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 144 in batch 1
# 2025-10-12 08:51:14,080 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 145 in batch 1
# 2025-10-12 08:51:14,082 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 146 in batch 1
# 2025-10-12 08:51:14,084 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 147 in batch 1
# 2025-10-12 08:51:14,085 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 148 in batch 1
# 2025-10-12 08:51:14,086 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 149 in batch 1
# 2025-10-12 08:51:14,086 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 150 in batch 1
# 2025-10-12 08:51:14,086 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 150 in batch 1
# 2025-10-12 08:51:14,087 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 151 in batch 1
# 2025-10-12 08:51:14,087 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 151 in batch 1
# 2025-10-12 08:51:14,087 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 152 in batch 1
# 2025-10-12 08:51:14,087 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 152 in batch 1
# 2025-10-12 08:51:14,088 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 153 in batch 1
# 2025-10-12 08:51:14,089 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 153 in batch 1
# 2025-10-12 08:51:14,090 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 154 in batch 1
# 2025-10-12 08:51:14,090 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 154 in batch 1
# 2025-10-12 08:51:14,091 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 155 in batch 1
# 2025-10-12 08:51:14,091 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 157 in batch 1
# 2025-10-12 08:51:14,091 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 157 in batch 1
# 2025-10-12 08:51:14,092 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 158 in batch 1
# 2025-10-12 08:51:14,092 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 158 in batch 1
# 2025-10-12 08:51:14,092 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 159 in batch 1
# 2025-10-12 08:51:14,093 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 159 in batch 1
# 2025-10-12 08:51:14,093 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 160 in batch 1
# 2025-10-12 08:51:14,094 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 160 in batch 1
# 2025-10-12 08:51:14,094 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 161 in batch 1
# 2025-10-12 08:51:14,094 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 161 in batch 1
# 2025-10-12 08:51:14,095 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 162 in batch 1
# 2025-10-12 08:51:14,095 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 162 in batch 1
# 2025-10-12 08:51:14,095 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 163 in batch 1
# 2025-10-12 08:51:14,096 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 163 in batch 1
# 2025-10-12 08:51:14,096 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 164 in batch 1
# 2025-10-12 08:51:14,096 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 164 in batch 1
# 2025-10-12 08:51:14,098 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 165 in batch 1
# 2025-10-12 08:51:14,098 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 165 in batch 1
# 2025-10-12 08:51:14,099 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 166 in batch 1
# 2025-10-12 08:51:14,099 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 166 in batch 1
# 2025-10-12 08:51:14,100 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 167 in batch 1
# 2025-10-12 08:51:14,100 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 167 in batch 1
# 2025-10-12 08:51:14,100 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 168 in batch 1
# 2025-10-12 08:51:14,100 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 168 in batch 1
# 2025-10-12 08:51:14,101 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 169 in batch 1
# 2025-10-12 08:51:14,101 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 169 in batch 1
# 2025-10-12 08:51:14,101 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 170 in batch 1
# 2025-10-12 08:51:14,101 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 170 in batch 1
# 2025-10-12 08:51:14,102 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 171 in batch 1
# 2025-10-12 08:51:14,102 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 171 in batch 1
# 2025-10-12 08:51:14,102 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 172 in batch 1
# 2025-10-12 08:51:14,102 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 172 in batch 1
# 2025-10-12 08:51:14,103 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 173 in batch 1
# 2025-10-12 08:51:14,103 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 173 in batch 1
# 2025-10-12 08:51:14,103 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 174 in batch 1
# 2025-10-12 08:51:14,105 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 174 in batch 1
# 2025-10-12 08:51:14,106 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 175 in batch 1
# 2025-10-12 08:51:14,106 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 175 in batch 1
# 2025-10-12 08:51:14,106 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 176 in batch 1
# 2025-10-12 08:51:14,107 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 176 in batch 1
# 2025-10-12 08:51:14,107 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 177 in batch 1
# 2025-10-12 08:51:14,107 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 177 in batch 1
# 2025-10-12 08:51:14,108 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 178 in batch 1
# 2025-10-12 08:51:14,108 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 178 in batch 1
# 2025-10-12 08:51:14,108 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 179 in batch 1
# 2025-10-12 08:51:14,108 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 179 in batch 1
# 2025-10-12 08:51:14,109 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 180 in batch 1
# 2025-10-12 08:51:14,109 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 180 in batch 1
# 2025-10-12 08:51:14,109 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 181 in batch 1
# 2025-10-12 08:51:14,109 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 181 in batch 1
# 2025-10-12 08:51:14,110 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 182 in batch 1
# 2025-10-12 08:51:14,112 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 182 in batch 1
# 2025-10-12 08:51:14,112 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 183 in batch 1
# 2025-10-12 08:51:14,112 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 183 in batch 1
# 2025-10-12 08:51:14,113 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 184 in batch 1
# 2025-10-12 08:51:14,113 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 184 in batch 1
# 2025-10-12 08:51:14,113 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 185 in batch 1
# 2025-10-12 08:51:14,113 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 186 in batch 1
# 2025-10-12 08:51:14,114 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 186 in batch 1
# 2025-10-12 08:51:14,114 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 187 in batch 1
# 2025-10-12 08:51:14,114 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 188 in batch 1
# 2025-10-12 08:51:14,114 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 188 in batch 1
# 2025-10-12 08:51:14,115 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 189 in batch 1
# 2025-10-12 08:51:14,115 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 189 in batch 1
# 2025-10-12 08:51:14,115 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 190 in batch 1
# 2025-10-12 08:51:14,115 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 190 in batch 1
# 2025-10-12 08:51:14,116 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 191 in batch 1
# 2025-10-12 08:51:14,116 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 191 in batch 1
# 2025-10-12 08:51:14,116 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 192 in batch 1
# 2025-10-12 08:51:14,116 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 192 in batch 1
# 2025-10-12 08:51:14,117 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 193 in batch 1
# 2025-10-12 08:51:14,117 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 193 in batch 1
# 2025-10-12 08:51:14,117 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 194 in batch 1
# 2025-10-12 08:51:14,117 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 194 in batch 1
# 2025-10-12 08:51:14,118 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 195 in batch 1
# 2025-10-12 08:51:14,118 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 195 in batch 1
# 2025-10-12 08:51:14,120 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 196 in batch 1
# 2025-10-12 08:51:14,120 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 196 in batch 1
# 2025-10-12 08:51:14,121 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 197 in batch 1
# 2025-10-12 08:51:14,121 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 197 in batch 1
# 2025-10-12 08:51:14,121 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 198 in batch 1
# 2025-10-12 08:51:14,122 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 198 in batch 1
# 2025-10-12 08:51:14,122 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 199 in batch 1
# 2025-10-12 08:51:14,122 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 199 in batch 1
# 2025-10-12 08:51:14,122 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 201 in batch 1
# 2025-10-12 08:51:14,123 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 201 in batch 1
# 2025-10-12 08:51:14,123 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 202 in batch 1
# 2025-10-12 08:51:14,123 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 202 in batch 1
# 2025-10-12 08:51:14,124 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 203 in batch 1
# 2025-10-12 08:51:14,124 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 203 in batch 1
# 2025-10-12 08:51:14,124 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 204 in batch 1
# 2025-10-12 08:51:14,126 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 204 in batch 1
# 2025-10-12 08:51:14,127 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 205 in batch 1
# 2025-10-12 08:51:14,127 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 205 in batch 1
# 2025-10-12 08:51:14,127 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 206 in batch 1
# 2025-10-12 08:51:14,128 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 206 in batch 1
# 2025-10-12 08:51:14,128 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 207 in batch 1
# 2025-10-12 08:51:14,129 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 207 in batch 1
# 2025-10-12 08:51:14,130 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 208 in batch 1
# 2025-10-12 08:51:14,130 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 208 in batch 1
# ...
# 2025-10-12 08:51:19,929 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 640 in batch 3
# 2025-10-12 08:51:19,929 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 641 in batch 3
# 2025-10-12 08:51:19,930 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 641 in batch 3
# 2025-10-12 08:51:19,931 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 642 in batch 3
# 2025-10-12 08:51:19,931 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 642 in batch 3
# 2025-10-12 08:51:19,931 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 643 in batch 3
# 2025-10-12 08:51:19,931 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 643 in batch 3
# 2025-10-12 08:51:19,932 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 644 in batch 3
# 2025-10-12 08:51:19,932 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 644 in batch 3
# 2025-10-12 08:51:19,932 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 645 in batch 3
# 2025-10-12 08:51:19,932 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 645 in batch 3
# 2025-10-12 08:51:19,933 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 646 in batch 3
# 2025-10-12 08:51:19,933 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 646 in batch 3
# 2025-10-12 08:51:19,933 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 647 in batch 3
# 2025-10-12 08:51:19,934 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 647 in batch 3
# 2025-10-12 08:51:19,934 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 648 in batch 3
# 2025-10-12 08:51:19,934 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 648 in batch 3
# 2025-10-12 08:51:19,934 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 649 in batch 3
# 2025-10-12 08:51:19,935 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 649 in batch 3
# 2025-10-12 08:51:19,935 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 650 in batch 3
# 2025-10-12 08:51:19,936 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 650 in batch 3
# 2025-10-12 08:51:19,936 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 651 in batch 3
# 2025-10-12 08:51:19,936 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 651 in batch 3
# 2025-10-12 08:51:19,936 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 652 in batch 3
# 2025-10-12 08:51:19,936 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 652 in batch 3
# 2025-10-12 08:51:19,937 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 653 in batch 3
# 2025-10-12 08:51:19,937 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 653 in batch 3
# 2025-10-12 08:51:19,937 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 654 in batch 3
# 2025-10-12 08:51:19,938 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 654 in batch 3
# 2025-10-12 08:51:19,938 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 655 in batch 3
# 2025-10-12 08:51:19,938 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 655 in batch 3
# 2025-10-12 08:51:19,938 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 656 in batch 3
# 2025-10-12 08:51:19,938 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 657 in batch 3
# 2025-10-12 08:51:19,939 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 657 in batch 3
# 2025-10-12 08:51:19,939 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 658 in batch 3
# 2025-10-12 08:51:19,939 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 658 in batch 3
# 2025-10-12 08:51:19,939 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 659 in batch 3
# 2025-10-12 08:51:19,940 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 659 in batch 3
# 2025-10-12 08:51:19,940 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 660 in batch 3
# 2025-10-12 08:51:19,941 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 660 in batch 3
# 2025-10-12 08:51:19,941 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 661 in batch 3
# 2025-10-12 08:51:19,941 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 661 in batch 3
# 2025-10-12 08:51:19,941 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 662 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 662 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 663 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 663 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 664 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 664 in batch 3
# 2025-10-12 08:51:19,942 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 665 in batch 3
# 2025-10-12 08:51:19,943 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 665 in batch 3
# 2025-10-12 08:51:19,943 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 666 in batch 3
# 2025-10-12 08:51:19,943 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 666 in batch 3
# 2025-10-12 08:51:19,943 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 667 in batch 3
# 2025-10-12 08:51:19,943 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 667 in batch 3
# 2025-10-12 08:51:19,944 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 668 in batch 3
# 2025-10-12 08:51:19,944 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 668 in batch 3
# 2025-10-12 08:51:19,945 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 669 in batch 3
# 2025-10-12 08:51:19,945 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 669 in batch 3
# 2025-10-12 08:51:19,945 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 670 in batch 3
# 2025-10-12 08:51:19,946 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 670 in batch 3
# 2025-10-12 08:51:19,946 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 671 in batch 3
# 2025-10-12 08:51:19,946 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 671 in batch 3
# 2025-10-12 08:51:19,947 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 672 in batch 3
# 2025-10-12 08:51:19,947 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 672 in batch 3
# 2025-10-12 08:51:19,947 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 673 in batch 3
# 2025-10-12 08:51:19,947 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 673 in batch 3
# 2025-10-12 08:51:19,948 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 674 in batch 3
# 2025-10-12 08:51:19,948 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 674 in batch 3
# 2025-10-12 08:51:19,948 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 675 in batch 3
# 2025-10-12 08:51:19,948 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 676 in batch 3
# 2025-10-12 08:51:19,949 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 677 in batch 3
# 2025-10-12 08:51:19,949 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 678 in batch 3
# 2025-10-12 08:51:19,950 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 679 in batch 3
# 2025-10-12 08:51:19,950 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 680 in batch 3
# 2025-10-12 08:51:19,950 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 683 in batch 3
# 2025-10-12 08:51:19,950 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 684 in batch 3
# 2025-10-12 08:51:19,951 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 685 in batch 3
# 2025-10-12 08:51:19,951 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 686 in batch 3
# 2025-10-12 08:51:19,951 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 686 in batch 3
# 2025-10-12 08:51:19,952 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 687 in batch 3
# 2025-10-12 08:51:19,952 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 687 in batch 3
# 2025-10-12 08:51:19,953 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 688 in batch 3
# 2025-10-12 08:51:19,953 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 688 in batch 3
# 2025-10-12 08:51:19,953 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 689 in batch 3
# 2025-10-12 08:51:19,953 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 689 in batch 3
# 2025-10-12 08:51:19,954 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 690 in batch 3
# 2025-10-12 08:51:19,954 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 690 in batch 3
# 2025-10-12 08:51:19,954 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 691 in batch 3
# 2025-10-12 08:51:19,954 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 691 in batch 3
# 2025-10-12 08:51:19,955 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 692 in batch 3
# 2025-10-12 08:51:19,955 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 692 in batch 3
# 2025-10-12 08:51:19,956 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 693 in batch 3
# 2025-10-12 08:51:19,957 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 693 in batch 3
# 2025-10-12 08:51:19,957 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 694 in batch 3
# 2025-10-12 08:51:19,957 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 694 in batch 3
# 2025-10-12 08:51:19,958 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 695 in batch 3
# 2025-10-12 08:51:19,958 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 695 in batch 3
# 2025-10-12 08:51:19,958 | WARNING | pyMut.annotate.actionable_mutation | Gene does not exist for variant at index 696 in batch 3
# 2025-10-12 08:51:19,958 | WARNING | pyMut.annotate.actionable_mutation | Unknown oncogenicity for variant at index 696 in batch 3
# 2025-10-12 08:51:19,982 | INFO | pyMut.annotate.actionable_mutation | Adding OncoKB annotations to self.data
# 2025-10-12 08:51:20,233 | INFO | pyMut.annotate.actionable_mutation | OncoKB annotation completed successfully: 2091 variants annotated
# Sample of MAF data after annotation:
#   CHROM        POS ID REF ALT QUAL FILTER TCGA-AB-2988 TCGA-AB-2869  \
# 0  chr9  100077177  .   T   C    .      .          T|T          T|T
# 1  chr9  100085148  .   G   A    .      .          G|G          G|G
# 2  chr9  100971322  .   A   C    .      .          A|A          A|A
# 3  chr9  104086335  .   C   T    .      .          C|C          C|C
# 4  chr9  104124840  .   G   A    .      .          G|A          G|G
#
#   TCGA-AB-3009  ... oncokb_variantSummary oncokb_tumorTypeSummary  \
# 0          T|T  ...                   NaN                     NaN
# 1          G|G  ...                   NaN                     NaN
# 2          A|A  ...                   NaN                     NaN
# 3          C|C  ...                   NaN                     NaN
# 4          G|G  ...                   NaN                     NaN
#
#   oncokb_prognosticSummary oncokb_diagnosticSummary  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   oncokb_diagnosticImplications oncokb_prognosticImplications  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   oncokb_treatments oncokb_dataVersion oncokb_lastUpdate oncokb_vus
# 0               NaN               v5.3        10/07/2025        NaN
# 1               NaN               v5.3        10/07/2025        NaN
# 2               NaN               v5.3        10/07/2025        NaN
# 3               NaN               v5.3        10/07/2025        NaN
# 4               NaN               v5.3        10/07/2025        NaN
#
# [5 rows x 234 columns]
# MAF File (GRCh37) - OncoKB annotation statistics:
#   oncokb_highestSensitiveLevel: 76 variants
#   oncokb_highestResistanceLevel: 15 variants
#   oncokb_highestDiagnosticImplicationLevel: 177 variants
#   oncokb_highestPrognosticImplicationLevel: 119 variants
#   oncokb_otherSignificantSensitiveLevels: 0 variants
#   oncokb_otherSignificantResistanceLevels: 0 variants
#   oncokb_hotspot: 91 variants
#   oncokb_geneSummary: 431 variants
#   oncokb_variantSummary: 425 variants
#   oncokb_tumorTypeSummary: 0 variants
#   oncokb_prognosticSummary: 0 variants
#   oncokb_diagnosticSummary: 0 variants
#   oncokb_diagnosticImplications: 177 variants
#   oncokb_prognosticImplications: 119 variants
#   oncokb_treatments: 76 variants
#   oncokb_dataVersion: 2091 variants
#   oncokb_lastUpdate: 2091 variants
#   oncokb_vus: 25 variants

# %% [markdown]
# ## Conclusion
#
# This notebook has demonstrated how to use the OncoKB annotation functionality to annotate genomic variants from a MAF file.

# %%
print("\n" + "=" * 80)
print("CONCLUSION")
print("=" * 80)

# Check if the MAF dataset was annotated
maf_oncokb_columns = [col for col in maf_py_mut.data.columns if col.startswith('oncokb_')]

if maf_oncokb_columns:
    # Show final annotation statistics
    maf_annotation_counts = {
        'Sensitivity': maf_py_mut.data['oncokb_highestSensitiveLevel'].notna().sum() if 'oncokb_highestSensitiveLevel' in maf_py_mut.data.columns else 0,
        'Resistance': maf_py_mut.data['oncokb_highestResistanceLevel'].notna().sum() if 'oncokb_highestResistanceLevel' in maf_py_mut.data.columns else 0,
        'Diagnostic': maf_py_mut.data['oncokb_highestDiagnosticImplicationLevel'].notna().sum() if 'oncokb_highestDiagnosticImplicationLevel' in maf_py_mut.data.columns else 0,
        'Prognostic': maf_py_mut.data['oncokb_highestPrognosticImplicationLevel'].notna().sum() if 'oncokb_highestPrognosticImplicationLevel' in maf_py_mut.data.columns else 0,
        'Hotspot': maf_py_mut.data['oncokb_hotspot'].sum() if 'oncokb_hotspot' in maf_py_mut.data.columns else 0,
        'VUS': maf_py_mut.data['oncokb_vus'].sum() if 'oncokb_vus' in maf_py_mut.data.columns else 0
    }
    
    # Create a DataFrame for final results
    results_df = pd.DataFrame({
        'MAF (GRCh37)': maf_annotation_counts
    })
    
    print("Final OncoKB annotation results for MAF file:")
    display(results_df)
    
    # Visualize results
    results_df.plot(kind='bar', figsize=(10, 6))
    plt.title('OncoKB Annotations for MAF File (GRCh37)')
    plt.xlabel('Annotation Type')
    plt.ylabel('Number of Variants')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    
    # Calculate annotation rate
    maf_total = len(maf_py_mut.data)
    maf_annotated = maf_py_mut.data[maf_py_mut.data['oncokb_highestSensitiveLevel'].notna() | 
                                    maf_py_mut.data['oncokb_highestResistanceLevel'].notna() | 
                                    maf_py_mut.data['oncokb_highestDiagnosticImplicationLevel'].notna() | 
                                    maf_py_mut.data['oncokb_highestPrognosticImplicationLevel'].notna()].shape[0] if all(col in maf_py_mut.data.columns for col in ['oncokb_highestSensitiveLevel', 'oncokb_highestResistanceLevel', 'oncokb_highestDiagnosticImplicationLevel', 'oncokb_highestPrognosticImplicationLevel']) else 0
    
    print(f"\nAnnotation rate: {maf_annotated}/{maf_total} variants annotated ({maf_annotated/maf_total*100:.2f}%)")
    
    print("\nSUMMARY:")
    print("This notebook successfully demonstrated how to:")
    print("1. Load OncoKB API token from .env file")
    print("2. Load a MAF file with GRCh37 assembly")
    print("3. Annotate variants with OncoKB actionable mutation data")
    print("4. Display annotation statistics and results")
    print("\nThe OncoKB annotations provide valuable information about the clinical actionability of variants.")
else:
    print("MAF dataset was not annotated successfully. Please check your OncoKB API token and try again.")
# Out:
# ================================================================================
# CONCLUSION
# ================================================================================
# Final OncoKB annotation results for MAF file:
#              MAF (GRCh37)
# Sensitivity            76
# Resistance             15
# Diagnostic            177
# Prognostic            119
# Hotspot                91
# VUS                    25
# Annotation rate: 207/2091 variants annotated (9.90%)
#
# SUMMARY:
# This notebook successfully demonstrated how to:
# 1. Load OncoKB API token from .env file
# 2. Load a MAF file with GRCh37 assembly
# 3. Annotate variants with OncoKB actionable mutation data
# 4. Display annotation statistics and results
#
# The OncoKB annotations provide valuable information about the clinical actionability of variants.
